# %% [markdown]
# # PyCity Schools Analysis
#
# The following analysis runs through a large dataset containing details about fifteen high schools. The data was analyzed through district, school, highest-performing schools, lowest-performing schools, math scores by grade, reading scores by grade, scores by school spending, scores by school size, and scores by school type summaries.
#
# Through this analysis, the highest-performing schools that had the most students pass with their math and reading scores above 70 were concluded to be of the charter school type. The secret to their success may be due to having excellent teachers distributed across all grades, because all of these highest-performing schools had 83% and above students pass with their math and reading scores in the 9th, 10th, 11th, and 12th grades.

# %%
# Import Packages
import pandas as pd
from pathlib import Path

# File Paths
load_school_data = Path("Resources/schools_complete.csv")
load_student_data = Path("Resources/students_complete.csv")

# Store Data Files in Pandas DataFrames
school_data = pd.read_csv(load_school_data)
student_data = pd.read_csv(load_student_data)

# Consolidate Data
all_school_data = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
all_school_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary

# %%
# Calculate Total Number of Unique Schools
school_count = len(all_school_data["school_name"].unique())
school_count
# Out:
# 15

# %%
# Calculate Total Number of Students
student_count = len(all_school_data["Student ID"].unique())
student_count
# Out:
# 39170

# %%
# Calculate the Total Budget
total_budget = sum(all_school_data["budget"].unique())
total_budget
# Out:
# 24649428

# %%
# Calculate Average Math Score
average_math_score = all_school_data["math_score"].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
# Calculate Average Reading Score
average_reading_score = all_school_data["reading_score"].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
# Calculate Percentage Passing Math
passing_math_count = all_school_data[(all_school_data["math_score"] >= 70)].count()["student_name"]
passing_math_percentage = passing_math_count / float(student_count) * 100
passing_math_percentage
# Out:
# 74.9808526933878

# %%
# Calculate Percentage Passing Reading
passing_reading_count = all_school_data[(all_school_data["reading_score"] >= 70)].count()["student_name"]
passing_reading_percentage = passing_reading_count / float(student_count) * 100
passing_reading_percentage
# Out:
# 85.80546336482001

# %%
# Calculate Overall Passing Rate for Students Passing Math and Reading
passing_math_reading_count = all_school_data[
    (all_school_data["math_score"] >= 70) & (all_school_data["reading_score"] >= 70)
].count()["student_name"]
overall_passing_rate = passing_math_reading_count /  float(student_count) * 100
overall_passing_rate
# Out:
# 65.17232575950983

# %%
# Create DataFrame for Calculations
district_summary = pd.DataFrame({
    "Total Schools": [school_count], "Total Students": [student_count], "Total Budget": [total_budget],
    "Average Math Score": [average_math_score], "Average Reading Score": [average_reading_score],
    "% Passing Math": [passing_math_percentage], "% Passing Reading": [passing_reading_percentage],
    "% Overall Passing": [overall_passing_rate]})
district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,.2f}".format)
district_summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %%
# Find All School Names
school_names = school_data["school_name"]

# %%
# Find All School Types
school_types = school_data["type"]

# %%
# Calculate Total Student Count Per School
per_school_counts = school_data["size"]

# %%
# Calculate Total School Budget and Budget Per Student
per_school_budget = school_data["budget"]
per_school_capita = per_school_budget / per_school_counts

# %%
# Calculate Average Math and Reading Score Per School
per_school_math = [student_data[(student_data["school_name"] == "Huang High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Figueroa High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Shelton High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Hernandez High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Griffin High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Wilson High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Cabrera High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Bailey High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Holden High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Pena High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Wright High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Rodriguez High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Johnson High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Ford High School")]["math_score"].mean(),
                   student_data[(student_data["school_name"] == "Thomas High School")]["math_score"].mean()]
per_school_reading = [student_data[(student_data["school_name"] == "Huang High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Figueroa High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Shelton High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Hernandez High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Griffin High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Wilson High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Cabrera High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Bailey High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Holden High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Pena High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Wright High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Rodriguez High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Johnson High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Ford High School")]["reading_score"].mean(),
                      student_data[(student_data["school_name"] == "Thomas High School")]["reading_score"].mean()]

# %%
# Calculate Number of Students Per School Passing Math
students_passing_math = student_data[(student_data["math_score"] >= 70)]
school_students_passing_math = students_passing_math.groupby(student_data["school_name"]).size()

# %%
# Calculate Number of Students Per School Passing Reading
students_passing_reading = student_data[(student_data["reading_score"] >= 70)]
school_students_passing_reading = students_passing_reading.groupby(student_data["school_name"]).size()

# %%
# Calculate Number of Students Per School Passing Overall
students_passing_math_and_reading = student_data[(student_data["reading_score"] >= 70) & (student_data["math_score"] >= 70)]
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()

# %%
# Calculate Passing Rates Per School for Math, Reading, and Overall
per_school_passing_math = [round(school_students_passing_math[7] / per_school_counts[0] * 100, 6),
                           round(school_students_passing_math[2] / per_school_counts[1] * 100, 6),
                           round(school_students_passing_math[11] / per_school_counts[2] * 100, 6),
                           round(school_students_passing_math[5] / per_school_counts[3] * 100, 6),
                           round(school_students_passing_math[4] / per_school_counts[4] * 100, 6),
                           round(school_students_passing_math[13] / per_school_counts[5] * 100, 6),
                           round(school_students_passing_math[1] / per_school_counts[6] * 100, 6),
                           round(school_students_passing_math[0] / per_school_counts[7] * 100, 6),
                           round(school_students_passing_math[6] / per_school_counts[8] * 100, 6),
                           round(school_students_passing_math[9] / per_school_counts[9] * 100, 6),
                           round(school_students_passing_math[14] / per_school_counts[10] * 100, 6),
                           round(school_students_passing_math[10] / per_school_counts[11] * 100, 6),
                           round(school_students_passing_math[8] / per_school_counts[12] * 100, 6),
                           round(school_students_passing_math[3] / per_school_counts[13] * 100, 6),
                           round(school_students_passing_math[12] / per_school_counts[14] * 100, 6)]
per_school_passing_reading = [round(school_students_passing_reading[7] / per_school_counts[0] * 100, 6),
                              round(school_students_passing_reading[2] / per_school_counts[1] * 100, 6),
                              round(school_students_passing_reading[11] / per_school_counts[2] * 100, 6),
                              round(school_students_passing_reading[5] / per_school_counts[3] * 100, 6),
                              round(school_students_passing_reading[4] / per_school_counts[4] * 100, 6),
                              round(school_students_passing_reading[13] / per_school_counts[5] * 100, 6),
                              round(school_students_passing_reading[1] / per_school_counts[6] * 100, 6),
                              round(school_students_passing_reading[0] / per_school_counts[7] * 100, 6),
                              round(school_students_passing_reading[6] / per_school_counts[8] * 100, 6),
                              round(school_students_passing_reading[9] / per_school_counts[9] * 100, 6),
                              round(school_students_passing_reading[14] / per_school_counts[10] * 100, 6),
                              round(school_students_passing_reading[10] / per_school_counts[11] * 100, 6),
                              round(school_students_passing_reading[8] / per_school_counts[12] * 100, 6),
                              round(school_students_passing_reading[3] / per_school_counts[13] * 100, 6),
                              round(school_students_passing_reading[12] / per_school_counts[14] * 100, 6)]
overall_passing_rate = [round(school_students_passing_math_and_reading[7] / per_school_counts[0] * 100, 6),
                        round(school_students_passing_math_and_reading[2] / per_school_counts[1] * 100, 6),
                        round(school_students_passing_math_and_reading[11] / per_school_counts[2] * 100, 6),
                        round(school_students_passing_math_and_reading[5] / per_school_counts[3] * 100, 6),
                        round(school_students_passing_math_and_reading[4] / per_school_counts[4] * 100, 6),
                        round(school_students_passing_math_and_reading[13] / per_school_counts[5] * 100, 6),
                        round(school_students_passing_math_and_reading[1] / per_school_counts[6] * 100, 6),
                        round(school_students_passing_math_and_reading[0] / per_school_counts[7] * 100, 6),
                        round(school_students_passing_math_and_reading[6] / per_school_counts[8] * 100, 6),
                        round(school_students_passing_math_and_reading[9] / per_school_counts[9] * 100, 6),
                        round(school_students_passing_math_and_reading[14] / per_school_counts[10] * 100, 6),
                        round(school_students_passing_math_and_reading[10] / per_school_counts[11] * 100, 6),
                        round(school_students_passing_math_and_reading[8] / per_school_counts[12] * 100, 6),
                        round(school_students_passing_math_and_reading[3] / per_school_counts[13] * 100, 6),
                        round(school_students_passing_math_and_reading[12] / per_school_counts[14] * 100, 6)]

# %%
# Create DataFrame for Calculations
per_school_summary = pd.DataFrame({
    "School Type": [school_types[0],school_types[1], school_types[2], school_types[3], school_types[4],
ataFrame
per_school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Bailey High School       District            4976       $3,124,928.00
# Holden High School        Charter             427         $248,087.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %% [markdown]
# ## Highest-Performing Schools (by % Overall Passing)

# %%
# Sort Schools by % Overall Passing and Display DataFrame for the Top 5 Schools
top_schools = pd.DataFrame({"% Overall Passing": [overall_passing_rate[6], overall_passing_rate[14], overall_passing_rate[4], overall_passing_rate[5], overall_passing_rate[9],
                            overall_passing_rate[10], overall_passing_rate[2], overall_passing_rate[8], overall_passing_rate[7], overall_passing_rate[13],
                            overall_passing_rate[12], overall_passing_rate[3], overall_passing_rate[0], overall_passing_rate[1], overall_passing_rate[11]]}, 
                            index = [school_names[6], school_names[14], school_names[4], school_names[5], school_names[9], school_names[10], school_names[2],
                            school_names[8], school_names[7], school_names[13], school_names[12], school_names[3], school_names[0], school_names[1], school_names[11]])

# Display Top 5 Schools
top_schools.head(5)
# Out:
#                      % Overall Passing
# Cabrera High School          91.334769
# Thomas High School           90.948012
# Griffin High School          90.599455
# Wilson High School           90.582567
# Pena High School             90.540541

# %% [markdown]
# ## Lowest-Performing Schools (by % Overall Passing)

# %%
# Sort the Schools by `% Overall Passing` and Display the Bottom 5 Schools
bottom_schools = pd.DataFrame({"% Overall Passing": [overall_passing_rate[11], overall_passing_rate[1], overall_passing_rate[0], overall_passing_rate[3], overall_passing_rate[12],
                            overall_passing_rate[13], overall_passing_rate[7], overall_passing_rate[8], overall_passing_rate[2], overall_passing_rate[10],
                            overall_passing_rate[9], overall_passing_rate[5], overall_passing_rate[4], overall_passing_rate[14], overall_passing_rate[6]]}, 
                            index = [school_names[11], school_names[1], school_names[0], school_names[3], school_names[12], school_names[13], school_names[7],
                            school_names[8], school_names[2], school_names[10], school_names[9], school_names[5], school_names[4], school_names[14], school_names[6]])

# Display Bottom 5 Schools
bottom_schools.head(5)
# Out:
#                        % Overall Passing
# Rodriguez High School          52.988247
# Figueroa High School           53.204476
# Huang High School              53.513884
# Hernandez High School          53.527508
# Johnson High School            53.539172

# %% [markdown]
# ## Math Scores by Grade

# %%
# Separate Data by Grade
ninth_graders = all_school_data[(all_school_data["grade"] == "9th")]
tenth_graders = all_school_data[(all_school_data["grade"] == "10th")]
eleventh_graders = all_school_data[(all_school_data["grade"] == "11th")]
twelfth_graders = all_school_data[(all_school_data["grade"] == "12th")]

# Group by School Name
ninth_grader_math_scores = ninth_graders.groupby(all_school_data["school_name"]).size()
tenth_grader_math_scores = tenth_graders.groupby(all_school_data["school_name"]).size()
eleventh_grader_math_scores = eleventh_graders.groupby(all_school_data["school_name"]).size()
twelfth_grader_math_scores = twelfth_graders.groupby(all_school_data["school_name"]).size()

# Calculate Mean of Math Scores and Combine Scores into DataFrame
average_math_ninth_grade = [round(ninth_graders[(ninth_graders["school_name"] == "Huang High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Figueroa High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Shelton High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Hernandez High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Griffin High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Wilson High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Cabrera High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Bailey High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Holden High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Pena High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Wright High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Rodriguez High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Johnson High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Ford High School")]["math_score"].mean(), 6),
                            round(ninth_graders[(ninth_graders["school_name"] == "Thomas High School")]["math_score"].mean(), 6)]
average_math_tenth_grade = [round(tenth_graders[(tenth_graders["school_name"] == "Huang High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Figueroa High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Shelton High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Hernandez High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Griffin High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Wilson High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Cabrera High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Bailey High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Holden High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Pena High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Wright High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Rodriguez High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Johnson High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Ford High School")]["math_score"].mean(), 6),
                            round(tenth_graders[(tenth_graders["school_name"] == "Thomas High School")]["math_score"].mean(), 6)]
average_math_eleventh_grade = [round(eleventh_graders[(eleventh_graders["school_name"] == "Huang High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Figueroa High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Shelton High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Hernandez High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Griffin High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Wilson High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Cabrera High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Bailey High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Holden High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Pena High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Wright High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Rodriguez High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Johnson High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Ford High School")]["math_score"].mean(), 6),
                               round(eleventh_graders[(eleventh_graders["school_name"] == "Thomas High School")]["math_score"].mean(), 6)]
average_math_twelfth_grade = [round(twelfth_graders[(twelfth_graders["school_name"] == "Huang High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Figueroa High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Shelton High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Hernandez High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Griffin High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Wilson High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Cabrera High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Bailey High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Holden High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Pena High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Wright High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Rodriguez High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Johnson High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Ford High School")]["math_score"].mean(), 6),
                              round(twelfth_graders[(twelfth_graders["school_name"] == "Thomas High School")]["math_score"].mean(), 6)]

math_scores_by_grade = pd.DataFrame({
    "9th": [average_math_ninth_grade[0],average_math_ninth_grade[1], average_math_ninth_grade[2], average_math_ninth_grade[3],
            average_math_ninth_grade[4], average_math_ninth_grade[5], average_math_ninth_grade[6], average_math_ninth_grade[7], 
            average_math_ninth_grade[8], average_math_ninth_grade[9], average_math_ninth_grade[10], average_math_ninth_grade[11],
            average_math_ninth_grade[12], average_math_ninth_grade[13], average_math_ninth_grade[14]],
    "10th": [average_math_tenth_grade[0],average_math_tenth_grade[1], average_math_tenth_grade[2], average_math_tenth_grade[3],
             average_math_tenth_grade[4], average_math_tenth_grade[5], average_math_tenth_grade[6], average_math_tenth_grade[7], 
             average_math_tenth_grade[8], average_math_tenth_grade[9], average_math_tenth_grade[10], average_math_tenth_grade[11],
             average_math_tenth_grade[12], average_math_tenth_grade[13], average_math_tenth_grade[14]],
    "11th": [average_math_eleventh_grade[0],average_math_eleventh_grade[1], average_math_eleventh_grade[2], average_math_eleventh_grade[3],
             average_math_eleventh_grade[4], average_math_eleventh_grade[5], average_math_eleventh_grade[6], average_math_eleventh_grade[7], 
             average_math_eleventh_grade[8], average_math_eleventh_grade[9], average_math_eleventh_grade[10], average_math_eleventh_grade[11],
             average_math_eleventh_grade[12], average_math_eleventh_grade[13], average_math_eleventh_grade[14]],
    "12th": [average_math_twelfth_grade[0],average_math_twelfth_grade[1], average_math_twelfth_grade[2], average_math_twelfth_grade[3],
             average_math_twelfth_grade[4], average_math_twelfth_grade[5], average_math_twelfth_grade[6], average_math_twelfth_grade[7], 
             average_math_twelfth_grade[8], average_math_twelfth_grade[9], average_math_twelfth_grade[10], average_math_twelfth_grade[11],
             average_math_twelfth_grade[12], average_math_twelfth_grade[13], average_math_twelfth_grade[14]]},
    index = school_names)

# Data Wrangling
math_scores_by_grade.index.name = None

# Display DataFrame
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Wright High School     83.264706  84.010288  83.836782  83.644986
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# ...

# %% [markdown]
# ## Reading Scores by Grade

# %%
# Separate Data by Grade
ninth_graders = all_school_data[(all_school_data["grade"] == "9th")]
tenth_graders = all_school_data[(all_school_data["grade"] == "10th")]
eleventh_graders = all_school_data[(all_school_data["grade"] == "11th")]
twelfth_graders = all_school_data[(all_school_data["grade"] == "12th")]

# Group by School Name
ninth_grader_reading_scores = ninth_graders.groupby(all_school_data["school_name"]).size()
tenth_grader_reading_scores = tenth_graders.groupby(all_school_data["school_name"]).size()
eleventh_grader_reading_scores = eleventh_graders.groupby(all_school_data["school_name"]).size()
twelfth_grader_reading_scores = twelfth_graders.groupby(all_school_data["school_name"]).size()

# Calculate Mean of Reading Scores and Combine Scores into DataFrame
average_reading_ninth_grade = [round(ninth_graders[(ninth_graders["school_name"] == "Huang High School")]["reading_score"].mean(), 6),
                               round(ninth_graders[(ninth_graders["school_name"] == "
                          per_school_passing_reading[10], per_school_passing_reading[11], per_school_passing_reading[12], per_school_passing_reading[13], per_school_passing_reading[14]],
    "% Overall Passing": [overall_passing_rate[0], overall_passing_rate[1], overall_passing_rate[2], overall_passing_rate[3], overall_passing_rate[4],
                          overall_passing_rate[5], overall_passing_rate[6], overall_passing_rate[7], overall_passing_rate[8], overall_passing_rate[9],
                          overall_passing_rate[10], overall_passing_rate[11], overall_passing_rate[12], overall_passing_rate[13], overall_passing_rate[14]]}, index = school_names)

# Data Wrangling
school_spending_df.index.name = None

# %%
# Categorize Spending (Per Student) Based on the Bins
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(school_spending_df["Per Student Budget"], 
                                                      spending_bins, labels=labels)

# Formatting
school_spending_df["Total School Budget"] = school_spending_df["Total School Budget"].map("${:,.2f}".format)
school_spending_df["Per Student Budget"] = school_spending_df["Per Student Budget"].map("${:,.2f}".format)

school_spending_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Bailey High School       District            4976       $3,124,928.00
# Holden High School        Charter             427         $248,087.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %%
# Calculate Averages for Columns
spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Math Score"].mean()
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
spending_passing_math = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Passing Math"].mean()
spending_passing_reading = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Passing Reading"].mean()
overall_passing_spending = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Overall Passing"].mean()

# %%
# Assemble DataFrame
spending_summary = pd.DataFrame({
    "Average Math Score": [spending_math_scores["<$585"], spending_math_scores["$585-630"], spending_math_scores["$630-645"],
                           spending_math_scores["$645-680"]],
    "Average Reading Score": [spending_reading_scores["<$585"], spending_reading_scores["$585-630"], spending_reading_scores["$630-645"],
                              spending_reading_scores["$645-680"]],
    "% Passing Math": [spending_passing_math["<$585"], spending_passing_math["$585-630"], spending_passing_math["$630-645"],
                       spending_passing_math["$645-680"]],
    "% Passing Reading": [spending_passing_reading["<$585"], spending_passing_reading["$585-630"], spending_passing_reading["$630-645"],
                          spending_passing_reading["$645-680"]],
    "% Overall Passing": [overall_passing_spending["<$585"], overall_passing_spending["$585-630"], overall_passing_spending["$630-645"],
                          overall_passing_spending["$645-680"]]}, index = ["<$585", "$585-630", "$630-645", "$645-680"])

# Data Wrangling
spending_summary.index.name = "Spending Ranges (Per Student)"

# Display Results
spending_summary
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-630                                81.899826              83.155286
# $630-645                                78.518855              81.624473
# $645-680                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-630                            87.133538          92.718205
# $630-645                            73.484209          84.391793
# $645-680                            66.164813          81.133951
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  90.369459
# $585-630                               81.418597
# ...

# %% [markdown]
# ## Scores by School Size

# %%
# Establish Bins
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Categorize Spending Based on the Bins
per_school_summary["School Size"] = per_school_summary["School Size"] = pd.cut(per_school_summary["Total Students"], 
                                                                        size_bins, labels=labels)
per_school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Bailey High School       District            4976       $3,124,928.00
# Holden High School        Charter             427         $248,087.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %%
# Calculate Averages for Columns
size_math_scores = per_school_summary.groupby(["School Size"])["Average Math Score"].mean()
size_reading_scores = per_school_summary.groupby(["School Size"])["Average Reading Score"].mean()
size_passing_math = per_school_summary.groupby(["School Size"])["% Passing Math"].mean()
size_passing_reading = per_school_summary.groupby(["School Size"])["% Passing Reading"].mean()
size_overall_passing = per_school_summary.groupby(["School Size"])["% Overall Passing"].mean()

# %%
# Use Scores to Create New DataFrame
size_summary = pd.DataFrame({
    "Average Math Score": [size_math_scores["Small (<1000)"], size_math_scores["Medium (1000-2000)"], size_math_scores["Large (2000-5000)"]],
    "Average Reading Score": [size_reading_scores["Small (<1000)"], size_reading_scores["Medium (1000-2000)"], size_reading_scores["Large (2000-5000)"]],
    "% Passing Math": [size_passing_math["Small (<1000)"], size_passing_math["Medium (1000-2000)"], size_passing_math["Large (2000-5000)"]],
    "% Passing Reading": [size_passing_reading["Small (<1000)"], size_passing_reading["Medium (1000-2000)"], size_passing_reading["Large (2000-5000)"]],
    "% Overall Passing": [size_overall_passing["Small (<1000)"], size_overall_passing["Medium (1000-2000)"], size_overall_passing["Large (2000-5000)"]]},
     index = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"])

# Data Wrangling
size_summary.index.name = "School Size"

# Display Results
size_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099436          89.883854
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %%
# Group DataFrame by School Type and Average Results
average_math_score_by_type = per_school_summary.groupby(["School Type"])["Average Math Score"].mean()
average_reading_score_by_type = per_school_summary.groupby(["School Type"])["Average Reading Score"].mean()
average_percent_passing_math_by_type = per_school_summary.groupby(["School Type"])["% Passing Math"].mean()
average_percent_passing_reading_by_type = per_school_summary.groupby(["School Type"])["% Passing Reading"].mean()
average_percent_overall_passing_by_type = per_school_summary.groupby(["School Type"])["% Overall Passing"].mean()

# %%
# Assemble Data by Type into DataFrame
type_summary = pd.DataFrame({
    "Average Math Score": [average_math_score_by_type["Charter"], average_math_score_by_type["District"]],
    "Average Reading Score": [average_reading_score_by_type["Charter"], average_reading_score_by_type["District"]],
    "% Passing Math": [average_percent_passing_math_by_type["Charter"], average_percent_passing_math_by_type["District"]],
    "% Passing Reading": [average_percent_passing_reading_by_type["Charter"], average_percent_passing_reading_by_type["District"]],
    "% Overall Passing": [average_percent_overall_passing_by_type["Charter"], average_percent_overall_passing_by_type["District"]]},
    index = ["Charter", "District"])

# Data Wrangling
type_summary.index.name = "School Type"

# Display Results
type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
